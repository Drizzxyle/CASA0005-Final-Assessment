# %%
import statsmodels.api as sm 
import statsmodels.formula.api as smf 
import statsmodels.graphics.api as smg 
import patsy 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns

# %%
df = pd.read_csv("HW11.csv")
y=df['MRR']
x1=df['>65']
x2=df['WHI']
x3=df['BHC']
x4=df['UemR']


model = smf.ols("y ~ x1 + x2 + x3", df) 
result = model.fit()
print(result.summary())
print('Parameters: ', results.params)
print('R2: ', results.rsquared)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.704
# Model:                            OLS   Adj. R-squared:                  0.527
# Method:                 Least Squares   F-statistic:                     3.965
# Date:                Tue, 19 Jan 2021   Prob (F-statistic):             0.0861
# Time:                        23:23:16   Log-Likelihood:                 14.495
# No. Observations:                   9   AIC:                            -20.99
# Df Residuals:                       5   BIC:                            -20.20
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.2464      0.938     -0.263      0.803      -2.658       2.165
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
import scipy.stats as stats
import pandas
 
df_train = pandas.read_csv('HWDC.csv')
print(df_train)
 
corrmat = df_train.corr()
 
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True)
# Out:
#                  Unnamed: 0    >65  WHI    BHC     MRR
# 0               North East   0.173  447  0.075   23.75
# 1                North West  0.166  451  0.068   99.25
# 2  Yorkshire and the Humber  0.165  454  0.060   63.25
# 3            East Midlands   0.169  450  0.061  159.75
# 4             West Midlands  0.170  459  0.055  130.00
# 5          East of England   0.175  521  0.046  169.25
# 6                   London   0.111  536  0.049  323.75
# 7                South East  0.171  544  0.044  355.25
# 8                South West  0.196  490  0.051   91.00
# <AxesSubplot:>

# %%
k=5
cols = corrmat.nlargest(k, 'MRR')['MRR'].index
cm = np.corrcoef(df_train[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

sns.regplot("WHI", "MRR", df, ax=ax1);
sns.regplot("BHC", "MRR", df, ax=ax2);


fig.tight_layout()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

sns.regplot(">65", "MRR", df, ax=ax1);
sns.regplot("UemR", "MRR", df, ax=ax);
fig.tight_layout()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
